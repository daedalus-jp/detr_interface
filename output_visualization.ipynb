# %%
# !pip install seaborn        
import os

# %%
# %cd detr

# detrのディレクトリ内に移動したことを確認
print(os.getcwd())
# Out:
# /workspace/src/others/cq_interface/detr
# /workspace/src/others/cq_interface/detr

# %%
from util.plot_utils import plot_logs
from pathlib import Path
import time
log_directory = [Path('./outputs')]
#log_directory = [Path('./outputs_without_dataaug')]
fields_of_interest = (
    'loss',
    'mAP',
)
plot_logs(log_directory, fields_of_interest)
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
